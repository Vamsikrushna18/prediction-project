# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
parkinsons_dataset=pd.read_csv("..//datasets//parkinsons.csv")

# %%
parkinsons_dataset.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
parkinsons_dataset.dtypes
# Out:
# name                 object
# MDVP:Fo(Hz)         float64
# MDVP:Fhi(Hz)        float64
# MDVP:Flo(Hz)        float64
# MDVP:Jitter(%)      float64
# MDVP:Jitter(Abs)    float64
# MDVP:RAP            float64
# MDVP:PPQ            float64
# Jitter:DDP          float64
# MDVP:Shimmer        float64
# MDVP:Shimmer(dB)    float64
# Shimmer:APQ3        float64
# Shimmer:APQ5        float64
# MDVP:APQ            float64
# Shimmer:DDA         float64
# NHR                 float64
# HNR                 float64
# status                int64
# RPDE                float64
# DFA                 float64
# spread1             float64
# spread2             float64
# D2                  float64
# PPE                 float64
# dtype: object

# %%
parkinsons_dataset.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
parkinsons_dataset.shape
# Out:
# (195, 24)

# %%
parkinsons_dataset['status']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 190    0
# 191    0
# 192    0
# 193    0
# 194    0
# Name: status, Length: 195, dtype: int64

# %%
parkinsons_dataset.dtypes
# Out:
# name                 object
# MDVP:Fo(Hz)         float64
# MDVP:Fhi(Hz)        float64
# MDVP:Flo(Hz)        float64
# MDVP:Jitter(%)      float64
# MDVP:Jitter(Abs)    float64
# MDVP:RAP            float64
# MDVP:PPQ            float64
# Jitter:DDP          float64
# MDVP:Shimmer        float64
# MDVP:Shimmer(dB)    float64
# Shimmer:APQ3        float64
# Shimmer:APQ5        float64
# MDVP:APQ            float64
# Shimmer:DDA         float64
# NHR                 float64
# HNR                 float64
# status                int64
# RPDE                float64
# DFA                 float64
# spread1             float64
# spread2             float64
# D2                  float64
# PPE                 float64
# dtype: object

# %%
# Select only numeric columns (excluding non-numeric columns like 'name' and 'status')
numeric_columns = parkinsons_dataset.select_dtypes(include=['number']).columns

# Group by 'status' and calculate the mean for the numeric columns only
grouped_mean = parkinsons_dataset[numeric_columns].groupby(parkinsons_dataset['status']).mean()

# Display the result
print(grouped_mean)
# Out:
#         MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# status
# 0        181.937771    223.636750    145.207292        0.003866
# 1        145.180762    188.441463    106.893558        0.006989
#
#         MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# status
# 0               0.000023  0.001925  0.002056    0.005776      0.017615
# 1               0.000051  0.003757  0.003900    0.011273      0.033658
#
#         MDVP:Shimmer(dB)  ...  Shimmer:DDA       NHR        HNR  status  \
# status                    ...
# 0               0.162958  ...     0.028511  0.011483  24.678750     0.0
# 1               0.321204  ...     0.053027  0.029211  20.974048     1.0
#
#             RPDE       DFA   spread1   spread2        D2       PPE
# status
# 0       0.442552  0.695716 -6.759264  0.160292  2.154491  0.123017
# 1       0.516816  0.725408 -5.333420  0.248133  2.456058  0.233828
#
# [2 rows x 23 columns]

# %%
x = parkinsons_dataset.drop(columns=['status'],axis=1)
y = parkinsons_dataset['status']

# %%
x.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    MDVP:APQ  Shimmer:DDA      NHR     HNR      RPDE       DFA   spread1  \
# ...

# %%
X_train , X_test , Y_train ,Y_test =train_test_split (x,y,test_size = 0.2 , random_state=42)

# %%
X_train.head()
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 5    phon_R01_S01_6      120.552       131.162       113.787         0.00968
# 135  phon_R01_S33_2      110.453       127.611       105.554         0.00494
# 122  phon_R01_S31_1      138.190       203.522        83.340         0.00704
# 167  phon_R01_S42_3      260.105       264.919       237.303         0.00339
# 85   phon_R01_S21_2      180.978       200.125       155.495         0.00406
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 5             0.00008   0.00463   0.00750     0.01388       0.04701  ...
# 135           0.00004   0.00244   0.00315     0.00731       0.04128  ...
# 122           0.00005   0.00406   0.00398     0.01218       0.04479  ...
# 167           0.00001   0.00205   0.00186     0.00616       0.02030  ...
# 85            0.00002   0.00220   0.00244     0.00659       0.03852  ...
#
# ...

# %%
X_test.head()
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 138  phon_R01_S33_5      112.239       126.609       104.095         0.00472
# 16   phon_R01_S04_5      144.188       349.259        82.764         0.00544
# 155  phon_R01_S37_3      117.870       127.349        95.654         0.00647
# 96   phon_R01_S22_6      159.116       168.913       144.811         0.00342
# 68   phon_R01_S18_3      143.533       162.215        65.809         0.01101
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 138           0.00004   0.00238   0.00290     0.00715       0.05643  ...
# 16            0.00004   0.00211   0.00292     0.00632       0.02047  ...
# 155           0.00005   0.00356   0.00300     0.01067       0.03087  ...
# 96            0.00002   0.00178   0.00184     0.00535       0.03381  ...
# 68            0.00008   0.00647   0.00467     0.01941       0.05384  ...
#
# ...

# %%
model = svm.SVC(kernel='linear')

# %%
# Drop non-numeric columns from X_train (e.g., the 'name' column or any other string column)
X_train_numeric = X_train.select_dtypes(include=['number'])

# Ensure Y_train is numeric (it should be, but this is to double-check)
Y_train_numeric = Y_train.astype('int')  # or 'float' depending on your dataset

# Fit the model using only numeric features
model.fit(X_train_numeric, Y_train_numeric)
# Out:
# SVC(kernel='linear')

# %%
# Drop the 'name' column (or any other non-numeric column) from both training and test sets
X_train_clean = X_train.drop(columns=['name'], axis=1)
X_test_clean = X_test.drop(columns=['name'], axis=1)

# Ensure that both train and test have the same columns in the same order
X_train_clean, X_test_clean = X_train_clean.align(X_test_clean, join='inner', axis=1)

# Now, you can fit the model again
model.fit(X_train_clean, Y_train)

# And make predictions
y_pred = model.predict(X_test_clean)

# %%
y_pred = model.predict(X_test_clean)

# %%
print(accuracy_score(Y_test,y_pred))
# Out:
# 0.8717948717948718

# %%
# Replace this with the correct feature values for a new person
input_data = (7, 136, 90, 33, 0, 34.0, 0.430, 50, 123.0, 154.2, 90.0, 0.005, 0.0015, 0.0234, 0.0275, 0.0435, 0.0182, -0.0291, 0.0165, 0.0149, 0.0340, 0.0564)  # Example input data with 22 features

# Convert the input data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# Reshape the data as the model expects 2D input
input_data_reshaped = input_data_as_numpy_array.reshape(1, -1)

# Make the prediction
prediction = model.predict(input_data_reshaped)

# Output the prediction
if prediction[0] == 0:
    print('The person does not have Parkinson\'s disease.')
else:
    print('The person has Parkinson\'s disease.')
# Out:
# The person has Parkinson's disease.
# C:\Users\VAMSI KRUSHNA\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
import pickle
filename = 'parkinsons_model.sav'
pickle.dump(model, open(filename, 'wb'))
